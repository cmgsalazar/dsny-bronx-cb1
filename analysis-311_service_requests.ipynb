# %%
import pandas as pd

# %%
df = pd.read_csv("raw-data/311_Service_Requests_from_2010_to_Present_20240923.csv")
df.dtypes
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_70989/1753943610.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("raw-data/311_Service_Requests_from_2010_to_Present_20240923.csv")
# Unique Key                          int64
# Created Date                       object
# Closed Date                        object
# Agency                             object
# Agency Name                        object
# Complaint Type                     object
# Descriptor                         object
# Location Type                      object
# Incident Zip                      float64
# Incident Address                   object
# Street Name                        object
# Cross Street 1                     object
# Cross Street 2                     object
# Intersection Street 1              object
# Intersection Street 2              object
# Address Type                       object
# ...

# %%
df["Complaint Type"].value_counts()
# Out:
# Complaint Type
# Graffiti                                  3647
# Sanitation Condition                      3421
# Derelict Vehicles                         3343
# Dirty Conditions                          3285
# Request Large Bulky Item Collection       2415
# Dirty Condition                           1917
# Missed Collection (All Materials)         1312
# Illegal Dumping                           1148
# Literature Request                         987
# Missed Collection                          697
# Other Enforcement                          514
# Snow                                       416
# Street Sweeping Complaint                  415
# Litter Basket / Request                    322
# Obstruction                                263
# Residential Disposal Complaint             219
# Vacant Lot                                 210
# Vendor Enforcement                         199
# Dead Animal                                196
# Litter Basket Request                      134
# ...

# %%
df["Descriptor"].value_counts()
# Out:
# Descriptor
# Graffiti                               3647
# Derelict Vehicles                      3343
# 15 Street Cond/Dump-Out/Drop-Off       2714
# Request Large Bulky Item Collection    2415
# Trash                                  2004
#                                        ...
# E30 Transfer Station                      1
# E99 Other Requests For Enforcement        1
# Collection Days                           1
# ER6 Comm. Recyc. (Comm. Tenant)           1
# 15X ICE-SNOW COND./PEDESTRN ACCESS        1
# Name: count, Length: 162, dtype: int64

# %%
df["Location Type"].value_counts()
# Out:
# Location Type
# Sidewalk                    11909
# Street                       8568
# Comercial                    1963
# Other                         988
# Mixed Use                     884
# Lot                           577
# Residential                   339
# Yard                           68
# Gutter                         14
# Alley                           5
# Traffic Island or Median        4
# Retail Store                    3
# Residence                       2
# Commercial Building             2
# Intersection                    1
# Non-Profit                      1
# Roadway                         1
# Name: count, dtype: int64

# %% [markdown]
# ### This filters 2024 data

# %%
df_2024 = df[df["Created Date"].str.contains("2024") == True]
df_2024
# Out:
#       Unique Key            Created Date             Closed Date Agency  \
# 0       62510564  09/20/2024 07:42:53 PM                     NaN   DSNY
# 1       62509299  09/20/2024 06:28:56 PM                     NaN   DSNY
# 2       62510573  09/20/2024 05:25:44 PM  09/20/2024 07:01:31 PM   DSNY
# 3       62514352  09/20/2024 03:53:41 PM                     NaN   DSNY
# 4       62514642  09/20/2024 02:55:00 PM  09/20/2024 11:10:00 PM   DSNY
# ...          ...                     ...                     ...    ...
# 2112    59909797  01/02/2024 09:47:07 AM  01/05/2024 12:48:37 PM   DSNY
# 2113    59909718  01/02/2024 09:14:50 AM  01/03/2024 11:55:39 AM   DSNY
# 2114    59903337  01/02/2024 06:21:11 AM  01/13/2024 10:15:16 AM   DSNY
# 2115    59898149  01/01/2024 03:07:38 PM  01/13/2024 09:41:00 AM   DSNY
# 2116    59895571  01/01/2024 09:38:18 AM  01/13/2024 09:40:59 AM   DSNY
#
#                    Agency Name      Complaint Type            Descriptor  \
# ...

# %%
df_2024.groupby("Borough")["Complaint Type"].value_counts()
# Out:
# Borough  Complaint Type
# BRONX    Dirty Condition                           678
#          Illegal Dumping                           364
#          Derelict Vehicles                         262
#          Vendor Enforcement                        141
#          Graffiti                                  131
#          Missed Collection                         114
#          Street Sweeping Complaint                 110
#          Obstruction                                77
#          Residential Disposal Complaint             52
#          Dead Animal                                46
#          Litter Basket Request                      32
#          Snow or Ice                                23
#          Commercial Disposal Complaint              20
#          Sanitation Worker or Vehicle Complaint     19
#          Dumpster Complaint                         16
#          Litter Basket Complaint                    14
#          Lot Condition                               8
# ...

# %%
df_2024["Complaint Type"].value_counts()
# Out:
# Complaint Type
# Dirty Condition                           678
# Illegal Dumping                           364
# Derelict Vehicles                         262
# Vendor Enforcement                        141
# Graffiti                                  131
# Missed Collection                         114
# Street Sweeping Complaint                 110
# Obstruction                                77
# Residential Disposal Complaint             52
# Dead Animal                                46
# Litter Basket Request                      32
# Snow or Ice                                23
# Commercial Disposal Complaint              20
# Sanitation Worker or Vehicle Complaint     19
# Dumpster Complaint                         16
# Litter Basket Complaint                    14
# Lot Condition                               8
# Abandoned Bike                              4
# Recycling Basket Complaint                  2
# Illegal Posting                             2
# ...

# %% [markdown]
# ### This filters 2024 data for Bronx Community Board 1

# %%
df_2024.groupby("Community Board")["Complaint Type"].value_counts()
# Out:
# Community Board  Complaint Type
# 01 BRONX         Dirty Condition                           678
#                  Illegal Dumping                           364
#                  Derelict Vehicles                         262
#                  Vendor Enforcement                        141
#                  Graffiti                                  131
#                  Missed Collection                         114
#                  Street Sweeping Complaint                 110
#                  Obstruction                                77
#                  Residential Disposal Complaint             52
#                  Dead Animal                                46
#                  Litter Basket Request                      32
#                  Snow or Ice                                23
#                  Commercial Disposal Complaint              20
#                  Sanitation Worker or Vehicle Complaint     19
# ...

# %%
df_2024["Complaint Type"].value_counts().sum()
# Out:
# 2117
