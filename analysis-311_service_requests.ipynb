# %%
import pandas as pd

# %%
df = pd.read_csv("raw-data/311_Service_Requests_from_2010_to_Present_20240923.csv")
df.dtypes
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_55418/1753943610.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("raw-data/311_Service_Requests_from_2010_to_Present_20240923.csv")
# Unique Key                          int64
# Created Date                       object
# Closed Date                        object
# Agency                             object
# Agency Name                        object
# Complaint Type                     object
# Descriptor                         object
# Location Type                      object
# Incident Zip                      float64
# Incident Address                   object
# Street Name                        object
# Cross Street 1                     object
# Cross Street 2                     object
# Intersection Street 1              object
# Intersection Street 2              object
# Address Type                       object
# City                               object
# Landmark                           object
# Facility Type                      object
# Status                             object
# Due Date                           object
# Resolution Description             object
# Resolution Action Updated Date     object
# Community Board                    object
# BBL                               float64
# Borough                            object
# X Coordinate (State Plane)        float64
# Y Coordinate (State Plane)        float64
# Open Data Channel Type             object
# Park Facility Name                 object
# Park Borough                       object
# Vehicle Type                      float64
# Taxi Company Borough              float64
# Taxi Pick Up Location             float64
# Bridge Highway Name               float64
# Bridge Highway Direction          float64
# Road Ramp                         float64
# Bridge Highway Segment            float64
# Latitude                          float64
# Longitude                         float64
# Location                           object
# dtype: object

# %%
df["Complaint Type"].value_counts()
# Out:
# Complaint Type
# Graffiti                                  3647
# Sanitation Condition                      3421
# Derelict Vehicles                         3343
# Dirty Conditions                          3285
# Request Large Bulky Item Collection       2415
# Dirty Condition                           1917
# Missed Collection (All Materials)         1312
# Illegal Dumping                           1148
# Literature Request                         987
# Missed Collection                          697
# Other Enforcement                          514
# Snow                                       416
# Street Sweeping Complaint                  415
# Litter Basket / Request                    322
# Obstruction                                263
# Residential Disposal Complaint             219
# Vacant Lot                                 210
# Vendor Enforcement                         199
# Dead Animal                                196
# Litter Basket Request                      134
# Overflowing Litter Baskets                 122
# Sanitation Worker or Vehicle Complaint      71
# Sweeping/Missed                             63
# Adopt-A-Basket                              59
# Commercial Disposal Complaint               51
# Snow or Ice                                 49
# Electronics Waste Appointment               46
# Lot Condition                               44
# Recycling Enforcement                       39
# Dumpster Complaint                          38
# Litter Basket Complaint                     36
# Sweeping/Missed-Inadequate                  29
# Abandoned Bike                              22
# Derelict Bicycle                            16
# Snow Removal                                16
# Sweeping/Inadequate                         14
# Collection Truck Noise                      14
# Storm                                        5
# Seasonal Collection                          3
# Illegal Posting                              3
# Request Xmas Tree Collection                 3
# Recycling Basket Complaint                   2
# Incorrect Data                               1
# Institution Disposal Complaint               1
# Name: count, dtype: int64

# %%
df["Descriptor"].value_counts()
# Out:
# Descriptor
# Graffiti                               3647
# Derelict Vehicles                      3343
# 15 Street Cond/Dump-Out/Drop-Off       2714
# Request Large Bulky Item Collection    2415
# Trash                                  2004
#                                        ...
# E30 Transfer Station                      1
# E99 Other Requests For Enforcement        1
# Collection Days                           1
# ER6 Comm. Recyc. (Comm. Tenant)           1
# 15X ICE-SNOW COND./PEDESTRN ACCESS        1
# Name: count, Length: 162, dtype: int64

# %%
df["Location Type"].value_counts()
# Out:
# Location Type
# Sidewalk                    11909
# Street                       8568
# Comercial                    1963
# Other                         988
# Mixed Use                     884
# Lot                           577
# Residential                   339
# Yard                           68
# Gutter                         14
# Alley                           5
# Traffic Island or Median        4
# Retail Store                    3
# Residence                       2
# Commercial Building             2
# Intersection                    1
# Non-Profit                      1
# Roadway                         1
# Name: count, dtype: int64

# %%
df
# Out:
#        Unique Key            Created Date             Closed Date Agency  \
# 0        62510564  09/20/2024 07:42:53 PM                     NaN   DSNY
# 1        62509299  09/20/2024 06:28:56 PM                     NaN   DSNY
# 2        62510573  09/20/2024 05:25:44 PM  09/20/2024 07:01:31 PM   DSNY
# 3        62514352  09/20/2024 03:53:41 PM                     NaN   DSNY
# 4        62514642  09/20/2024 02:55:00 PM  09/20/2024 11:10:00 PM   DSNY
# ...           ...                     ...                     ...    ...
# 25802    15645817  01/03/2010 06:15:00 PM  01/04/2010 12:00:00 PM   DSNY
# 25803    15645618  01/03/2010 03:42:00 PM  01/04/2010 12:00:00 PM   DSNY
# 25804    15645547  01/03/2010 10:50:00 AM  01/04/2010 12:00:00 PM   DSNY
# 25805    15645798  01/03/2010 10:30:00 AM  01/04/2010 12:00:00 PM   DSNY
# 25806    15645243  01/02/2010 03:11:00 PM  01/04/2010 12:00:00 PM   DSNY
#
#                     Agency Name                     Complaint Type  \
# 0      Department of Sanitation                    Dirty Condition
# 1      Department of Sanitation                    Dirty Condition
# 2      Department of Sanitation                 Vendor Enforcement
# 3      Department of Sanitation                 Dumpster Complaint
# 4      Department of Sanitation                  Derelict Vehicles
# ...                         ...                                ...
# 25802  Department of Sanitation  Missed Collection (All Materials)
# 25803  Department of Sanitation  Missed Collection (All Materials)
# 25804  Department of Sanitation  Missed Collection (All Materials)
# 25805  Department of Sanitation  Missed Collection (All Materials)
# 25806  Department of Sanitation                   Dirty Conditions
#
#                               Descriptor Location Type  Incident Zip  \
# 0                                  Trash        Street       10451.0
# 1                                  Trash      Sidewalk       10455.0
# 2                        Non-Food Vendor        Street       10455.0
# 3                   Overflowing dumpster        Street       10454.0
# 4                      Derelict Vehicles        Street       10455.0
# ...                                  ...           ...           ...
# 25802  1R Missed Recycling-All Materials      Sidewalk       10454.0
# 25803  1R Missed Recycling-All Materials      Sidewalk       10455.0
# 25804  1R Missed Recycling-All Materials      Sidewalk       10454.0
# 25805  1R Missed Recycling-All Materials      Sidewalk       10455.0
# 25806            E3A Dirty Area/Alleyway           Lot       10455.0
#
#            Incident Address  ... Vehicle Type Taxi Company Borough  \
# 0       107 EXTERIOR STREET  ...          NaN                  NaN
# 1          671 BROOK AVENUE  ...          NaN                  NaN
# 2          467 BROOK AVENUE  ...          NaN                  NaN
# 3      512 EAST  145 STREET  ...          NaN                  NaN
# 4      844 EAST  155 STREET  ...          NaN                  NaN
# ...                     ...  ...          ...                  ...
# 25802    288 CYPRESS AVENUE  ...          NaN                  NaN
# 25803   535 EAST 148 STREET  ...          NaN                  NaN
# 25804   596 EAST 139 STREET  ...          NaN                  NaN
# 25805    504 CONCORD AVENUE  ...          NaN                  NaN
# 25806  659 CAULDWELL AVENUE  ...          NaN                  NaN
#
#       Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction  \
# 0                       NaN                 NaN                      NaN
# 1                       NaN                 NaN                      NaN
# 2                       NaN                 NaN                      NaN
# 3                       NaN                 NaN                      NaN
# 4                       NaN                 NaN                      NaN
# ...                     ...                 ...                      ...
# 25802                   NaN                 NaN                      NaN
# 25803                   NaN                 NaN                      NaN
# 25804                   NaN                 NaN                      NaN
# 25805                   NaN                 NaN                      NaN
# 25806                   NaN                 NaN                      NaN
#
#       Road Ramp Bridge Highway Segment   Latitude  Longitude  \
# 0           NaN                    NaN  40.812503 -73.932070
# 1           NaN                    NaN  40.817793 -73.913324
# 2           NaN                    NaN  40.812920 -73.916131
# 3           NaN                    NaN  40.812171 -73.916081
# 4           NaN                    NaN  40.816374 -73.903333
# ...         ...                    ...        ...        ...
# 25802       NaN                    NaN  40.806652 -73.913888
# 25803       NaN                    NaN  40.813907 -73.914215
# 25804       NaN                    NaN  40.807046 -73.915950
# 25805       NaN                    NaN  40.812058 -73.908498
# 25806       NaN                    NaN  40.816909 -73.909521
#
#                                       Location
# 0      (40.81250265321616, -73.93206963529377)
# 1      (40.81779288693678, -73.91332445037834)
# 2      (40.81292033695046, -73.91613053991559)
# 3      (40.81217099154582, -73.91608090876606)
# 4        (40.81637415697892, -73.903333402825)
# ...                                        ...
# 25802  (40.80665247902638, -73.91388801695683)
# 25803  (40.81390702735288, -73.91421460460222)
# 25804  (40.80704649658228, -73.91595010414282)
# 25805  (40.81205817884614, -73.90849835900477)
# 25806   (40.8169089099845, -73.90952133453698)
#
# [25807 rows x 41 columns]
