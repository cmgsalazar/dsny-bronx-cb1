# %%
import pandas as pd

# %%
# initializing 311 service requests data

df = pd.read_csv("raw-data/Department_of_Sanitation_311_Service_Requests20240922.csv")
df.dtypes
# Out:
# Unique Key                          int64
# Created Date                       object
# Closed Date                        object
# Agency                             object
# Agency Name                        object
# Complaint Type                     object
# Descriptor                         object
# Location Type                      object
# Incident Zip                      float64
# Incident Address                   object
# Street Name                        object
# Cross Street 1                     object
# Cross Street 2                     object
# Intersection Street 1              object
# Intersection Street 2              object
# Address Type                       object
# City                               object
# Landmark                          float64
# Facility Type                      object
# Status                             object
# Due Date                           object
# Resolution Action Updated Date     object
# ...

# %%
len(df)
# Out:
# 3361

# %%
# counting data per borough

df["Borough"].value_counts()
# Out:
# Borough
# BROOKLYN         1161
# QUEENS           1058
# MANHATTAN         403
# BRONX             396
# STATEN ISLAND     328
# Unspecified        15
# Name: count, dtype: int64

# %%
# filtering only Bronx boroughs

bronx_df = df[df["Borough"] == "BRONX"]

# %%
# summing up per Community Board

bronx_df["Community Board"].value_counts()
# Out:
# Community Board
# 12 BRONX             89
# 10 BRONX             47
# 09 BRONX             44
# 11 BRONX             37
# 04 BRONX             35
# 06 BRONX             28
# 05 BRONX             25
# 07 BRONX             23
# 03 BRONX             20
# 08 BRONX             19
# 01 BRONX             14
# 02 BRONX             13
# Unspecified BRONX     2
# Name: count, dtype: int64

# %%
# filtering only Bronx community board 1 (Port Morris, Melrose, Mott Haven)

bronx_cb1_df = bronx_df[bronx_df["Community Board"] == "01 BRONX"]

# %%
bronx_cb1_df
# Out:
#       Unique Key            Created Date             Closed Date Agency  \
# 78      23345061  06/01/2012 08:14:00 AM  06/01/2012 12:00:00 PM   DSNY
# 439     23344349  06/01/2012 03:01:00 PM  06/05/2012 12:00:00 PM   DSNY
# 593     23349562  06/02/2012 09:31:00 AM  06/02/2012 12:00:00 PM   DSNY
# 889     23352390  06/03/2012 12:46:00 PM  06/06/2012 12:00:00 PM   DSNY
# 1354    23354612  06/04/2012 01:01:00 PM  06/04/2012 01:01:00 PM   DSNY
# 1356    23356420  06/04/2012 01:01:00 PM  06/04/2012 01:01:00 PM   DSNY
# 1374    23356183  06/04/2012 01:16:00 PM  06/04/2012 01:16:00 PM   DSNY
# 1447    23358532  06/04/2012 03:08:00 PM  06/05/2012 12:00:00 PM   DSNY
# 2618    23374510  06/06/2012 03:37:00 PM  06/07/2012 12:00:00 PM   DSNY
# 2779    23372875  06/06/2012 11:16:00 PM  06/07/2012 12:00:00 PM   DSNY
# 2833    23378317  06/07/2012 08:12:00 AM  06/07/2012 12:00:00 PM   DSNY
# 3062    23379920  06/07/2012 12:46:03 PM  06/27/2012 12:00:00 AM   DSNY
# ...

# %%
# Wait... Why are they all from 2012?

# %%
df["Created Date"].max()
# Out:
# '06/07/2012 12:55:59 PM'
